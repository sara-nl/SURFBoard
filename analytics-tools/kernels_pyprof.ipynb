# %%
import pandas as pd
pd.set_option('display.max_rows', 90)

# %% [markdown]
# # CUDA kernel durations 1 node vs 8 nodes
#
# There is no difference in the kernel used (and their durations) between 1 and 8 nodes experiments both for dali-gpu and dali-cpu-to-gpu

# %%
def kernel_durations(file, direction='fprop'):
    assert direction in ['fprop', 'bprop']
    df = pd.read_parquet(file, index=0)
    
    df_direction = df[df['Direction'] == direction][['Kernel', 'Sil(ns)']]
    return df_direction.groupby('Kernel').sum().sort_values(by='Sil(ns)', ascending=False) * 1E-9

# %% [markdown]
# ## dali-cpu-to-gpu

# %%
filename = 'data/pcm/run_0_config_1_2_ib_nvprof_2_resnet50_dali-cpu-to-gpu_32_fp16_fp32_ret_0_0.gzip'
node1 = kernel_durations(filename)
filename = 'data/pcm/run_0_config_8_2_ib_nvprof_2_resnet50_dali-cpu-to-gpu_32_fp16_fp32_ret_0_0.gzip'
node8 = kernel_durations(filename)

duration_kernels = node1.merge(node8, left_on='Kernel', right_on='Kernel', suffixes=('_1node', '_8node'))
duration_kernels.rename(columns={'Sil(ns)_1node': '1 node', 'Sil(ns)_8node': '8 nodes'})
# Out:
#                                                       1 node   8 nodes
# Kernel
# cudnn::detail::implicit_convolve_sgemm              6.037096  5.987010
# elementwise_kernel                                  3.279977  3.276931
# cudnn::detail::wgrad_alg0_engine                    3.183431  3.465039
# sgemm_sm35_ldg_nn_64x16x64x16x16                    2.578240  2.552302
# sgemm_sm35_ldg_nt_64x16x64x16x16                    2.168583  2.145964
# sgemm_largek_lds64                                  1.732891  1.710166
# cudnn::detail::dgrad_engine                         1.574014  1.562378
# cudnn::detail::dgrad_alg1_engine                    1.228442  1.219383
# cudnn::detail::bn_bw_1C11_kernel_new                1.165348  1.162638
# cudnn::detail::bn_fw_tr_1C11_kernel_NCHW            1.038966  1.038086
# cudnn::detail::wgrad_alg1_engine                    0.655925  0.410776
# cgemm_strided_batched_sm35_ldg_nt_64x8x64x16x16     0.506704  0.502916
# cudnn::detail::bn_fw_tr_1C11_singleread             0.356361  0.355412
# cudnn::winograd_nonfused::winogradForwardOutput4x4  0.356212  0.354492
# cudnn_convolve_sgemm_sm35_ldg_nn_64x16x64x16x16     0.315533  0.312000
# cudnn::winograd_nonfused::winogradForwardData4x4    0.293700  0.292186
# cudnn_dgrad_sm35_ldg_nt_64x16x64x16x16              0.232117  0.229505
# fermiPlusCgemmLDS128_batched                        0.228437  0.226854
# fft2d_r2c_32x32                                     0.219403  0.218481
# cudnn_dgrad_sm35_ldg_nt_32x16x64x8x16               0.202380  0.200543
# scalePackedTensor_kernel                            0.187043  0.183747
# sgemm_sm35_ldg_nt_128x8x128x16x16                   0.179911  0.179157
# cudnn_dgrad_sm35_ldg_nt_64x16x128x8x32              0.175529  0.173851
# cgemm_sm35_ldg_tn_64x8x64x16x16                     0.170303  0.167284
# kernelPointwiseApply2                               0.162068  0.160063
# MaxPoolBackward                                     0.146469  0.145741
# pointwise_mult_and_sum_complex                      0.144378  0.142533
# cudnn::winograd_nonfused::winogradWgradData4x4      0.119856  0.119561
# fft2d_r2c_16x16                                     0.113101  0.111571
# MaxPoolForward                                      0.100542  0.098871
# scal_kernel                                         0.087578  0.087044
# cudnn::winograd_nonfused::winogradWgradDelta4x4     0.085673  0.085633
# cudnn::winograd_nonfused::winogradForwardFilter4x4  0.075118  0.075125
# cudnn::detail::bn_bw_1C11_singleread                0.071111  0.070428
# fft1d_r2c_32                                        0.060253  0.059887
# fft2d_c2r_32x32                                     0.058530  0.058972
# fft2d_c2r_16x16                                     0.056224  0.055617
# cudnn::winograd::winograd3x3Kernel                  0.052425  0.051958
# fft2d_r2c_64x64                                     0.051108  0.050456
# cudnn::detail::dgrad2d_alg1_1                       0.046070  0.045440
# im2col4d_kernel                                     0.044454  0.044215
# flip_filter                                         0.041746  0.041260
# cudnn::winograd_nonfused::winogradWgradOutput4x4    0.027884  0.027794
# fft2d_c2r_64x64                                     0.027399  0.027063
# fft1d_c2r_32                                        0.019110  0.019022
# reduce_kernel                                       0.016722  0.016489
# cudnn_convolve_sgemm_sm35_ldg_nn_32x16x64x8x16      0.005128  0.005100
# sgemm_sm_heavy_nt_ldg                               0.004727  0.004667
# sgemm_sm35_ldg_nt_128x16x64x16x16                   0.001150  0.001155
# cunn_SoftMaxForward                                 0.000766  0.000791
# cudnn::winograd::generateWinogradTilesKernel        0.000452  0.000454
# cunn_ClassNLLCriterion_updateOutput_kernel          0.000375  0.000405
# cunn_SoftMaxBackward                                0.000253  0.000247
# cunn_ClassNLLCriterion_updateGradInput_kernel       0.000138  0.000126
# kernelPointwiseApply1                               0.000100  0.000099
# compute_gemm_pointers                               0.000078  0.000078

# %% [markdown]
# ## dali-gpu

# %%
filename = 'data/pcm/run_0_config_1_2_ib_nvprof_2_resnet50_dali-gpu_32_fp16_fp32_ret_0_0.gzip'
node1 = kernel_durations(filename)
filename = 'data/pcm/run_0_config_8_2_ib_nvprof_2_resnet50_dali-gpu_32_fp16_fp32_ret_0_0.gzip'
node8 = kernel_durations(filename)

duration_kernels = node1.merge(node8, left_on='Kernel', right_on='Kernel', suffixes=('_1node', '_8node'))
duration_kernels.rename(columns={'Sil(ns)_1node': '1 node', 'Sil(ns)_8node': '8 nodes'})
# Out:
#                                                       1 node   8 nodes
# Kernel
# cudnn::detail::implicit_convolve_sgemm              6.036142  5.755177
# elementwise_kernel                                  3.283388  3.283576
# cudnn::detail::wgrad_alg0_engine                    3.184476  3.168416
# sgemm_sm35_ldg_nn_64x16x64x16x16                    2.582502  2.550685
# sgemm_sm35_ldg_nt_64x16x64x16x16                    2.173917  2.140859
# sgemm_largek_lds64                                  1.725359  1.706284
# cudnn::detail::dgrad_engine                         1.573836  1.789154
# cudnn::detail::dgrad_alg1_engine                    1.228878  1.032957
# cudnn::detail::bn_bw_1C11_kernel_new                1.163904  1.162276
# cudnn::detail::bn_fw_tr_1C11_kernel_NCHW            1.039746  1.041324
# cudnn::detail::wgrad_alg1_engine                    0.656680  0.653411
# cgemm_strided_batched_sm35_ldg_nt_64x8x64x16x16     0.506705  0.503034
# cudnn::winograd_nonfused::winogradForwardOutput4x4  0.358503  0.354802
# cudnn::detail::bn_fw_tr_1C11_singleread             0.356312  0.355409
# cudnn_convolve_sgemm_sm35_ldg_nn_64x16x64x16x16     0.315657  0.529095
# cudnn::winograd_nonfused::winogradForwardData4x4    0.293421  0.292969
# cudnn_dgrad_sm35_ldg_nt_64x16x64x16x16              0.232354  0.229522
# fermiPlusCgemmLDS128_batched                        0.228121  0.226901
# fft2d_r2c_32x32                                     0.218577  0.217358
# cudnn_dgrad_sm35_ldg_nt_32x16x64x8x16               0.202274  0.200646
# scalePackedTensor_kernel                            0.186904  0.183793
# sgemm_sm35_ldg_nt_128x8x128x16x16                   0.181132  0.179353
# cudnn_dgrad_sm35_ldg_nt_64x16x128x8x32              0.175550  0.173806
# cgemm_sm35_ldg_tn_64x8x64x16x16                     0.169874  0.168133
# kernelPointwiseApply2                               0.161665  0.160789
# MaxPoolBackward                                     0.147305  0.145960
# pointwise_mult_and_sum_complex                      0.144443  0.143115
# cudnn::winograd_nonfused::winogradWgradData4x4      0.120123  0.119308
# fft2d_r2c_16x16                                     0.113043  0.111559
# MaxPoolForward                                      0.100433  0.099224
# scal_kernel                                         0.086114  0.085933
# cudnn::winograd_nonfused::winogradWgradDelta4x4     0.085632  0.085823
# cudnn::winograd_nonfused::winogradForwardFilter4x4  0.075129  0.075090
# cudnn::detail::bn_bw_1C11_singleread                0.070827  0.070878
# dali::kernels::resampling::BatchedSeparableResa...  0.060339  0.061889
# fft1d_r2c_32                                        0.060244  0.059990
# fft2d_c2r_32x32                                     0.058840  0.059457
# fft2d_c2r_16x16                                     0.056230  0.055651
# cudnn::winograd::winograd3x3Kernel                  0.052449  0.052062
# fft2d_r2c_64x64                                     0.051051  0.050467
# cudnn::detail::dgrad2d_alg1_1                       0.046109  0.045452
# im2col4d_kernel                                     0.044518  0.058373
# flip_filter                                         0.041707  0.041210
# nvjpeg::dctQuantInvJpegKernel                       0.036793  0.045724
# dali::kernels::detail::SliceFlipNormalizePermut...  0.035307  0.034800
# cudnn::winograd_nonfused::winogradWgradOutput4x4    0.027904  0.027609
# fft2d_c2r_64x64                                     0.027500  0.027082
# fft1d_c2r_32                                        0.019039  0.018977
# reduce_kernel                                       0.016690  0.016465
# nvjpeg::ycbcr_to_format_kernel_roi                  0.014720  0.016858
# cudnn_convolve_sgemm_sm35_ldg_nn_32x16x64x8x16      0.005122  0.005098
# sgemm_sm_heavy_nt_ldg                               0.004721  0.004675
# nvjpeg::dcAcDecodeKernel                            0.001599  0.001587
# nvjpeg::transposeKernel                             0.001580  0.001565
# sgemm_sm35_ldg_nt_128x16x64x16x16                   0.001014  0.001123
# cunn_SoftMaxForward                                 0.000789  0.000770
# cudnn::winograd::generateWinogradTilesKernel        0.000450  0.000450
# cunn_ClassNLLCriterion_updateOutput_kernel          0.000428  0.000422
# nvjpeg::destuffKernel                               0.000374  0.000397
# cunn_SoftMaxBackward                                0.000254  0.000241
# nvjpeg::dcPrefixSumDownWriteKernel                  0.000155  0.000153
# nvjpeg::dcPrefixSumReadUpKernel                     0.000137  0.000142
# nvjpeg::dcPrefixSumUpUpDownDownKernel               0.000131  0.000133
# cunn_ClassNLLCriterion_updateGradInput_kernel       0.000126  0.000126
# kernelPointwiseApply1                               0.000117  0.000120
# compute_gemm_pointers                               0.000070  0.000078
