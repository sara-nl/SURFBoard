# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 90)
df = pd.read_csv('data/pcm/init_times.csv')

# %% [markdown]
# ## Initialization times for each configuration
# - init time: initialization time computed as the difference between the timestamp of the begining of the 2nd batch (2nd forward pass marker) and the timestamp of the begining of the experiment. The init time includes the first batch
# - 1st batch: duration of the first batch to put the initialization time into perspective

# %%
df
# Out:
#     node  workers           loader  batch_size  grad  init  1st batch
# 0      1        2  dali-cpu-to-gpu          32  fp16  17.0       12.5
# 1      1        2  dali-cpu-to-gpu          32  fp32  19.0       14.3
# 2      1        2  dali-cpu-to-gpu          64  fp16  31.2       24.4
# 3      1        2  dali-cpu-to-gpu          64  fp32  25.8       17.5
# 4      1        2         dali-gpu          32  fp16  15.8       13.5
# 5      1        2         dali-gpu          32  fp32  16.6       15.5
# 6      1        2         dali-gpu          64  fp16  19.5       18.0
# 7      1        2         dali-gpu          64  fp32  20.6       19.0
# 8      1        8  dali-cpu-to-gpu          32  fp16  21.3       16.4
# 9      1        8  dali-cpu-to-gpu          32  fp32  17.8       12.3
# 10     1        8  dali-cpu-to-gpu          64  fp16  26.0       17.2
# 11     1        8  dali-cpu-to-gpu          64  fp32  25.6       16.9
# ...
